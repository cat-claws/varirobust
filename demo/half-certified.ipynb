# %%
# !git add .
# !git commit -m tolist
# !git push

# %%
# !git pull

# %%
# git add .
# git commit -m tolist
# git push

# %%
import torch
import torch.nn.functional as F

from utils import experiment, iterate
from mnist_models import ConvNet

m = ConvNet()
m = m.to('cuda' if torch.cuda.is_available() else 'cpu')

# ckpt = 'checkpoints/ConvNet.pt'
ckpt = 'checkpoints/ConvNet_TRADES.pt'
# ckpt = 'checkpoints/ConvNet_CVaR.pt'

m.load_state_dict({k:torch.load(ckpt)[k] for k in m.state_dict()})
# Out:
# <All keys matched successfully>

# %%
with torch.no_grad():
    outputs = iterate.predict(m,
                              iterate.mnist_delta_predict_step_l2,
                              device = 'cuda',
                              val_set = experiment.train_set,
                              batch_size = 1000
                             )
print(outputs.keys(), outputs['predictions'])
# Out:
# dict_keys(['predictions', 'correct', 'samples']) [11.05000114440918, 8.65000057220459, 13.750001907348633, 7.150002479553223, 7.550001621246338, 17.999998092651367, 5.700000286102295, 14.899999618530273, 8.64999771118164, 10.05000114440918, 12.899998664855957, 8.70000171661377, 17.050003051757812, 13.700000762939453, 5.550001621246338, 11.400004386901855, 20.0, 20.0, 10.35000228881836, 7.5500006675720215, 10.049997329711914, 10.349998474121094, 6.150001049041748, 7.850001335144043, 5.850000381469727, 11.199999809265137, 12.600003242492676, 18.14999771118164, 18.69999885559082, 6.600002765655518, 12.40000057220459, 20.0, 14.049999237060547, 7.399999618530273, 9.850001335144043, 11.000000953674316, 8.5, 11.750001907348633, 10.700004577636719, 13.200002670288086, 8.950000762939453, 20.0, 5.849997520446777, 8.300002098083496, 14.450000762939453, 11.100000381469727, 20.0, 9.700000762939453, 5.650001525878906, 15.90000057220459, 16.19999885559082, 13.150001525878906, 9.800000190734863, 6.600002288818359, 0.0, 20.0, 9.249998092651367, 8.300000190734863, 13.400001525878906, 7.950000762939453, 12.15000057220459, 12.44999885559082, 9.20000171661377, 9.100001335144043, 13.200002670288086, 9.20000171661377, 12.900002479553223, 8.35000228881836, 12.200000762939453, 9.499998092651367, 6.400001525878906, 11.099998474121094, 7.250001430511475, 12.300002098083496, 14.100000381469727, 6.30000114440918, 11.449999809265137, 8.550003051757812, 6.600001335144043, 11.05000114440918, 0.0, 11.700002670288086, 20.0, 14.30000114440918, 11.199999809265137, 20.0, 11.700000762939453, 9.799999237060547, 11.200000762939453, 11.700000762939453, 12.999995231628418, 12.750000953674316, 12.649998664855957, 12.249999046325684, 20.0, 11.55000114440918, 9.400001525878906, 20.0, 15.049997329711914, 7.80000114440918, 10.750003814697266, 10.70000171661377, 5.000000476837158, 10.050002098083496, 9.200000762939453, 3.9499998092651367, 9.400001525878906, 14.499999046325684, 9.800003051757812, 6.900000095367432, 1.5999994277954102, 13.850004196166992, 9.200000762939453, 6.650001525878906, 14.550000190734863, 12.59999942779541, 8.100004196166992, 11.150002479553223, 9.800000190734863, 14.550000190734863, 17.650001525878906, 15.899999618530273, 20.0, 12.350001335144043, 9.149999618530273, 20.0, 9.350005149841309, 13.300004005432129, 8.550002098083496, 10.400001525878906, 15.649998664855957, 14.799999237060547, 0.0, 8.80000114440918, 7.150001049041748, 15.499999046325684, 14.650002479553223, 16.200000762939453, 9.05000114440918, 13.400001525878906, 5.700001239776611, 9.149999618530273, 11.20000171661377, 12.800000190734863, 20.0, 11.40000057220459, 18.25, 10.900002479553223, 6.350001335144043, 13.149999618530273, 12.40000057220459, 12.299999237060547, 8.85000228881836, 5.300001621246338, 7.6500020027160645, 11.799999237060547, 13.04999828338623, 12.40000057220459, 7.899999141693115, 15.499999046325684, 20.0, 12.299999237060547, 10.10000228881836, 11.450000762939453, 14.550002098083496, 13.199999809265137, 13.600001335144043, 10.199999809265137, 7.25, 6.800000190734863, 9.899999618530273, 14.100001335144043, 3.1000030040740967, 9.699999809265137, 8.050002098083496, 10.499999046325684, 7.350001335144043, 7.850001335144043, 20.0, 13.199999809265137, 18.999998092651367, 12.649999618530273, 13.950000762939453, 8.200000762939453, 5.65000057220459, 12.699997901916504, 11.449999809265137, 18.199996948242188, 20.0, 10.90000057220459, 19.29999542236328, 8.14999771118164, 9.75, 12.900001525878906, 13.550000190734863, 8.35000228881836, 13.550000190734863, 20.0, 13.550000190734863, 13.800003051757812, 7.850003242492676, 9.050000190734863, 20.0, 13.69999885559082, 11.949999809265137, 7.750001907348633, 10.749998092651367, 10.59999942779541, 6.050001621246338, 13.650002479553223, 6.7000017166137695, 7.600005149841309, 6.050002098083496, 20.0, 10.75000286102295, 18.249998092651367, 10.500000953674316, 12.60000228881836, 13.200003623962402, 13.350000381469727, 16.04999542236328, 11.999998092 ...

# %%
outputs['predictions'][0]
# Out:
# 11.05000114440918

# %%
import matplotlib.pyplot as plt

plt.hist(outputs['correct'], bins = 100)
plt.show()

# %%
plt.hist(outputs['predictions'], bins = 100)
plt.show()

# %%
import numpy as np
from sklearn.neighbors import KDTree

# %%
train_X = experiment.train_set.data / 255
train_X = train_X.view(len(train_X), -1).numpy()
train_tree = KDTree(train_X, leaf_size=2)

# %%
test_X = experiment.val_set.data / 255
test_X = test_X.view(len(test_X), -1).numpy()
test_tree = KDTree(test_X, leaf_size=2)

# %%
from tqdm.notebook import trange
all_in = set()
for i in trange(len(train_X)):
    ind = test_tree.query_radius(train_X[i:i+1], r=outputs['predictions'][i])
    all_in.update(set(ind[0].tolist()))
    if len(all_in) == len(test_X):
        break

# ind = tree.query_radius(X[:1], r=0.3)  
# print(ind)  # indices of neighbors within distance 0.3
# Out:
#   0%|          | 0/60000 [00:00<?, ?it/s]

# %%
len(all_in)
# Out:
# 10000
